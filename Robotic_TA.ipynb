# %% [markdown]
# <a href="https://colab.research.google.com/github/faezesarlakifar/---test---/blob/main/Robotic_TA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Calender
# @markdown Feel free to ask any questions about homeworks from your TAs. ;)❤️
from IPython.display import IFrame
link_id = "1Vz1X1yaGxyUCdl7Gwv-gAYtTT2caEERhJfBRac9w7Fw/edit?usp=sharing"
print(f"If you want to download the calender: https://docs.google.com/spreadsheets/d/{link_id}/")
IFrame(src=f"https://docs.google.com/spreadsheets/d/{link_id}/?direct%26mode=render%26action=download%26mode=render", width=1200, height=700)
# Out:
# If you want to download the calender: https://docs.google.com/spreadsheets/d/1Vz1X1yaGxyUCdl7Gwv-gAYtTT2caEERhJfBRac9w7Fw/edit?usp=sharing/
#         <iframe
#             width="1200"
#             height="700"
#             src="https://docs.google.com/spreadsheets/d/1Vz1X1yaGxyUCdl7Gwv-gAYtTT2caEERhJfBRac9w7Fw/edit?usp=sharing/?direct%26mode=render%26action=download%26mode=render"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# @title Team Members
# @markdown Each homework assignment will be completed by groups of three members. ☕️
from IPython.display import IFrame
link_id = "1yebHZbFwlbjn6whBrPqTRWY8_8chv8KCbK4NczN91yE/edit?usp=sharing"
print(f"If you want to add your group members: https://docs.google.com/spreadsheets/d/{link_id}/")
IFrame(src=f"https://docs.google.com/spreadsheets/d/{link_id}/?direct%26mode=render%26action=download%26mode=render", width=570, height=680)
# Out:
# If you want to add your group members: https://docs.google.com/spreadsheets/d/1yebHZbFwlbjn6whBrPqTRWY8_8chv8KCbK4NczN91yE/edit?usp=sharing/
#         <iframe
#             width="570"
#             height="680"
#             src="https://docs.google.com/spreadsheets/d/1yebHZbFwlbjn6whBrPqTRWY8_8chv8KCbK4NczN91yE/edit?usp=sharing/?direct%26mode=render%26action=download%26mode=render"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# @title Generated by AI Robot Images
# @markdown Let me know if you have any creative ideas for generating new images from text. ;) <br> There might be a bonus for that. 😃
import cv2
from matplotlib import pyplot as plt

# create figure
fig = plt.figure(figsize=(15, 15))

# setting values to rows and column variables
rows = 3
columns = 3

# reading images
Image1 = cv2.imread('1.png')
Image2 = cv2.imread('2.png')
Image3 = cv2.imread('3.png')
Image4 = cv2.imread('4.png')
Image5 = cv2.imread('5.png')
Image6 = cv2.imread('6.png')
Image7 = cv2.imread('7.png')
Image8 = cv2.imread('8.png')
Image9 = cv2.imread('9.png')

# Adds a subplot at the 1st position
fig.add_subplot(rows, columns, 1)

# showing image
plt.imshow(cv2.cvtColor(Image1, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title("First")

# Adds a subplot at the 2nd position
fig.add_subplot(rows, columns, 2)

# showing image
plt.imshow(cv2.cvtColor(Image2, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title("Second")

# Adds a subplot at the 3rd position
fig.add_subplot(rows, columns, 3)

# showing image
plt.imshow(cv2.cvtColor(Image3, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title("Third")

# Adds a subplot at the 4th position
fig.add_subplot(rows, columns, 4)

# showing image
plt.imshow(cv2.cvtColor(Image4, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title("Fourth")

# Adds a subplot at the 5th position
fig.add_subplot(rows, columns, 5)

# showing image
plt.imshow(cv2.cvtColor(Image5, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title("Fifth")

# Adds a subplot at the 4th position
fig.add_subplot(rows, columns, 6)

# showing image
plt.imshow(cv2.cvtColor(Image6, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title("Sixth")

# Adds a subplot at the 4th position
fig.add_subplot(rows, columns, 7)

# showing image
plt.imshow(cv2.cvtColor(Image7, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title("Seventh")

# Adds a subplot at the 4th position
fig.add_subplot(rows, columns, 8)

# showing image
plt.imshow(cv2.cvtColor(Image8, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title("Eighth")

# Adds a subplot at the 4th position
fig.add_subplot(rows, columns, 9)

# showing image
plt.imshow(cv2.cvtColor(Image9, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title("Ninth")

print()
